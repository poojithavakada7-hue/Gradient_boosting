# %% [markdown]
# <a href="https://colab.research.google.com/github/poojithavakada7-hue/Gradient_boosting/blob/main/Gradient_boosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Training Data
X_train = np.array([[1], [2], [3], [6], [7], [8]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# Create Model
model = GradientBoostingClassifier(
    n_estimators=100,      # number of trees
    learning_rate=0.1,     # step size
    max_depth=3,
    random_state=42
)

# Train Model
model.fit(X_train, y_train)

# Test Data
X_test = np.array([[40]])

# Predict
prediction = model.predict(X_test)

print("Predicted Class (0=Fail, 1=Pass):", prediction[0])
# Out:
# Predicted Class (0=Fail, 1=Pass): 1

# %%
X_test2 = np.array([[6], [6], [3]])
y_test2 = np.array([0, 1, 1])

predictions = model.predict(X_test2)

print("Predictions:", predictions)
print("Accuracy:", accuracy_score(y_test2, predictions))
# Out:
# Predictions: [1 1 0]
# Accuracy: 0.3333333333333333
